# %% [markdown]
# <a href="https://colab.research.google.com/github/MakSi27/DA-Retail-Profit-Leakage-Analysis/blob/main/data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hi')
# Out:
# hi
